# %% [markdown]
# # <span style="font-width:bold; font-size: 3rem; color:#1EB182;"> **Air Quality** </span><span style="font-width:bold; font-size: 3rem; color:#333;">- Part 04: Batch Inference</span>
#
# ## 🗒️ This notebook is divided into the following sections:
#
# 1. Download model and batch inference data
# 2. Make predictions, generate PNG for forecast
# 3. Store predictions in a monitoring feature group adn generate PNG for hindcast

# %% [markdown]
# ## <span style='color:#ff5f27'> 📝 Imports

# %%
import sys
from pathlib import Path

def is_google_colab() -> bool:
    if "google.colab" in str(get_ipython()):
        return True
    return False

def clone_repository() -> None:
    # !git clone https://github.com/featurestorebook/mlfs-book.git
    # %cd mlfs-book

def install_dependencies() -> None:
    # !pip install --upgrade uv
    # !uv pip install --all-extras --system --requirement pyproject.toml


if is_google_colab():
    clone_repository()
    install_dependencies()
    root_dir = str(Path().absolute())
    print("Google Colab environment")
else:
    root_dir = Path().absolute()
    # Strip ~/notebooks/ccfraud from PYTHON_PATH if notebook started in one of these subdirectories
    if root_dir.parts[-1:] == ('airquality',):
        root_dir = Path(*root_dir.parts[:-1])
    if root_dir.parts[-1:] == ('notebooks',):
        root_dir = Path(*root_dir.parts[:-1])
    root_dir = str(root_dir) 
    print("Local environment")

# Add the root directory to the `PYTHONPATH` to use the `recsys` Python module from the notebook.
if root_dir not in sys.path:
    sys.path.append(root_dir)
print(f"Added the following directory to the PYTHONPATH: {root_dir}")
    
# Read the API keys and configuration variables from the file <root_dir>/.env
from mlfs import config
settings = config.HopsworksSettings(_env_file=f"{root_dir}/.env")
# Out:
# Local environment
# Added the following directory to the PYTHONPATH: /mnt/c/Users/t-kaspermalm/Documents/code/github/kth/mlfs-book
# HopsworksSettings initialized!

# %%
import datetime
import pandas as pd
from xgboost import XGBRegressor
import hopsworks
import json
from mlfs.airquality import util
import os

# %%
today = datetime.datetime.now() - datetime.timedelta(0)
tomorrow = today + datetime.timedelta(days = 1)
today
# Out:
# datetime.datetime(2025, 11, 17, 21, 11, 12, 519282)

# %% [markdown]
# ## <span style="color:#ff5f27;"> 📡 Connect to Hopsworks Feature Store </span>

# %%
project = hopsworks.login(engine="python")
fs = project.get_feature_store() 

secrets = hopsworks.get_secrets_api()
location_str = secrets.get_secret("SENSOR_LOCATION_JSON").value
location = json.loads(location_str)
country=location['country']
city=location['city']
street=location['street']
# Out:
# 2025-11-17 21:11:12,543 INFO: Initializing external client
# 2025-11-17 21:11:12,544 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-11-17 21:11:13,290 WARNING: UserWarning: The installed hopsworks client version 4.4.2 may not be compatible with the connected Hopsworks backend version 4.2.2.
# To ensure compatibility please install the latest bug fix release matching the minor version of your backend (4.2) by running 'pip install hopsworks==4.2.*'
# 2025-11-17 21:11:14,209 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1271978

# %% [markdown]
# ## <span style="color:#ff5f27;">🪝 Download the model from Model Registry</span>

# %%
mr = project.get_model_registry()

retrieved_model = mr.get_model(
    name="air_quality_xgboost_model_cloud_cover_lag",
    version=4,
)

fv = retrieved_model.get_feature_view()

# Download the saved model artifacts to a local directory
saved_model_dir = retrieved_model.download()
# Out:
# 2025-11-17 21:11:16,676 INFO: There is no parent information
# Downloading: 0.000%|          | 0/543499 elapsed<00:00 remaining<?
# Downloading model artifact (0 dirs, 1 files)...
# Downloading: 0.000%|          | 0/104685 elapsed<00:00 remaining<?
# Downloading model artifact (0 dirs, 2 files)...
# Downloading: 0.000%|          | 0/51218 elapsed<00:00 remaining<?
# Downloading model artifact (1 dirs, 3 files)...
# Downloading: 0.000%|          | 0/16325 elapsed<00:00 remaining<?
# Downloading model artifact (1 dirs, 4 files)... DONE

# %%
# Loading the XGBoost regressor model and label encoder from the saved model directory
# retrieved_xgboost_model = joblib.load(saved_model_dir + "/xgboost_regressor.pkl")
retrieved_xgboost_model = XGBRegressor()

retrieved_xgboost_model.load_model(saved_model_dir + "/model.json")

# Displaying the retrieved XGBoost regressor model
retrieved_xgboost_model
# Out:
# XGBRegressor(base_score='4.5132874E1', booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None,
#              feature_types=['float', 'float', 'float', 'float', 'float',
#                             'float', 'float', 'float', 'float', 'float',
#                             'float', 'float', 'float', 'float', 'floa...
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ## <span style="color:#ff5f27;">✨ Get Weather Forecast Features with Feature View   </span>

# %%
weather_fg = fs.get_feature_group(
    name='weather',
    version=1,
)
batch_data = weather_fg.filter(weather_fg.date >= today).read()
batch_data
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (-1.91s)
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2025-11-19 00:00:00+00:00                 2.05                0.4
# 1 2025-11-18 00:00:00+00:00                 0.25                0.0
# 2 2025-11-23 00:00:00+00:00                -1.25                0.0
# 3 2025-11-22 00:00:00+00:00                 5.75                0.0
# 4 2025-11-20 00:00:00+00:00                 5.20                0.0
# 5 2025-11-21 00:00:00+00:00                 5.60                0.0
#
#    wind_speed_10m_max  wind_direction_10m_dominant    city
# 0            2.545584                   224.999893  berlin
# 1           11.520000                   270.000000  berlin
# 2            2.305125                   321.340179  berlin
# 3            9.360000                   360.000000  berlin
# 4            6.214563                    10.007925  berlin
# 5            3.096837                   215.537766  berlin

# %%
import pandas as pd

today_str = pd.to_datetime(today).strftime('%Y-%m-%d')

cloud_cover_fg = fs.get_feature_group(
    name='cloud_cover',
    version=1,
)
cloud_cover_batch_data = cloud_cover_fg.filter(cloud_cover_fg.date >= today_str).read()
cloud_cover_batch_data
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (0.75s)
#          date  cloud_cover    city
# 0  2025-11-17           41  berlin
# 1  2025-11-21           90  berlin
# 2  2025-11-20           99  berlin
# 3  2025-11-23           40  berlin
# 4  2025-11-22           93  berlin
# 5  2025-11-18           52  berlin
# 6  2025-11-19           92  berlin

# %% [markdown]
# ### <span style="color:#ff5f27;">🤖 Making the predictions</span>

# %%
import pandas as pd

# Ensure both 'date' columns are datetime (no timezone)
batch_data['date'] = pd.to_datetime(batch_data['date']).dt.tz_localize(None)
cloud_cover_batch_data['date'] = pd.to_datetime(cloud_cover_batch_data['date']).dt.tz_localize(None)

# Merge cloud_cover
batch_data = batch_data.merge(
    cloud_cover_batch_data[['date', 'cloud_cover']],
    on='date',
    how='left'
)

# %%
batch_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         6 non-null      datetime64[us]
#  1   temperature_2m_mean          6 non-null      float32
#  2   precipitation_sum            6 non-null      float32
#  3   wind_speed_10m_max           6 non-null      float32
#  4   wind_direction_10m_dominant  6 non-null      float32
#  5   city                         6 non-null      object
#  6   cloud_cover                  6 non-null      int64
# dtypes: datetime64[us](1), float32(4), int64(1), object(1)
# memory usage: 368.0+ bytes

# %%
lag_days = [1, 2, 3]
lag_features = ['temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 
                'wind_direction_10m_dominant', 'cloud_cover']

for col in lag_features:
    for lag in lag_days:
        batch_data[f"{col}_minus_{lag}"] = batch_data[col].shift(lag)

# %%
batch_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   date                                 6 non-null      datetime64[us]
#  1   temperature_2m_mean                  6 non-null      float32
#  2   precipitation_sum                    6 non-null      float32
#  3   wind_speed_10m_max                   6 non-null      float32
#  4   wind_direction_10m_dominant          6 non-null      float32
#  5   city                                 6 non-null      object
#  6   cloud_cover                          6 non-null      int64
#  7   temperature_2m_mean_minus_1          5 non-null      float32
#  8   temperature_2m_mean_minus_2          4 non-null      float32
#  9   temperature_2m_mean_minus_3          3 non-null      float32
#  10  precipitation_sum_minus_1            5 non-null      float32
#  11  precipitation_sum_minus_2            4 non-null      float32
#  12  precipitation_sum_minus_3            3 non-null      float32
#  13  wind_speed_10m_max_minus_1           5 non-null      float32
#  14  wind_speed_10m_max_minus_2           4 non-null      float32
#  15  wind_speed_10m_max_minus_3           3 non-null      float32
#  16  wind_direction_10m_dominant_minus_1  5 non-null      float32
#  17  wind_direction_10m_dominant_minus_2  4 non-null      float32
#  18  wind_direction_10m_dominant_minus_3  3 non-null      float32
#  19  cloud_cover_minus_1                  5 non-null      float64
#  20  cloud_cover_minus_2                  4 non-null      float64
#  21  cloud_cover_minus_3                  3 non-null      float64
# dtypes: datetime64[us](1), float32(16), float64(3), int64(1), object(1)
# memory usage: 800.0+ bytes

# %%
import pandas as pd

# Ensure both 'date' columns are datetime (no timezone)
batch_data['date'] = pd.to_datetime(batch_data['date']).dt.tz_localize(None)
cloud_cover_batch_data['date'] = pd.to_datetime(cloud_cover_batch_data['date']).dt.tz_localize(None)

# Merge cloud_cover
"""
batch_data = batch_data.merge(
    cloud_cover_batch_data[['date', 'cloud_cover']],
    on='date',
    how='left'
)
"""
batch_data.info()

"""
# Predict
batch_data['predicted_pm25'] = retrieved_xgboost_model.predict(
    batch_data[['temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 'wind_direction_10m_dominant', 'cloud_cover']]
)
"""

batch_data['predicted_pm25'] = retrieved_xgboost_model.predict(
    batch_data[['temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 'wind_direction_10m_dominant', 'cloud_cover', 'temperature_2m_mean_minus_1', 'temperature_2m_mean_minus_2', 'temperature_2m_mean_minus_3', 'precipitation_sum_minus_1', 'precipitation_sum_minus_2', 'precipitation_sum_minus_3', 'wind_speed_10m_max_minus_1', 'wind_speed_10m_max_minus_2', 'wind_speed_10m_max_minus_3', 'wind_direction_10m_dominant_minus_1', 'wind_direction_10m_dominant_minus_2', 'wind_direction_10m_dominant_minus_3', 'cloud_cover_minus_1', 'cloud_cover_minus_2', 'cloud_cover_minus_3']]
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   date                                 6 non-null      datetime64[us]
#  1   temperature_2m_mean                  6 non-null      float32
#  2   precipitation_sum                    6 non-null      float32
#  3   wind_speed_10m_max                   6 non-null      float32
#  4   wind_direction_10m_dominant          6 non-null      float32
#  5   city                                 6 non-null      object
#  6   cloud_cover                          6 non-null      int64
#  7   temperature_2m_mean_minus_1          5 non-null      float32
#  8   temperature_2m_mean_minus_2          4 non-null      float32
#  9   temperature_2m_mean_minus_3          3 non-null      float32
#  10  precipitation_sum_minus_1            5 non-null      float32
#  11  precipitation_sum_minus_2            4 non-null      float32
#  12  precipitation_sum_minus_3            3 non-null      float32
#  13  wind_speed_10m_max_minus_1           5 non-null      float32
#  14  wind_speed_10m_max_minus_2           4 non-null      float32
#  15  wind_speed_10m_max_minus_3           3 non-null      float32
#  16  wind_direction_10m_dominant_minus_1  5 non-null      float32
#  17  wind_direction_10m_dominant_minus_2  4 non-null      float32
#  18  wind_direction_10m_dominant_minus_3  3 non-null      float32
#  19  cloud_cover_minus_1                  5 non-null      float64
#  20  cloud_cover_minus_2                  4 non-null      float64
#  21  cloud_cover_minus_3                  3 non-null      float64
# dtypes: datetime64[us](1), float32(16), float64(3), int64(1), object(1)
# memory usage: 800.0+ bytes

# %%
lag_days = [1, 2, 3]
lag_features = ['temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 
                'wind_direction_10m_dominant', 'cloud_cover']

for col in lag_features:
    for lag in lag_days:
        batch_data[f"{col}_minus_{lag}"] = batch_data[col].shift(lag)

# %%
batch_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   date                                 6 non-null      datetime64[us]
#  1   temperature_2m_mean                  6 non-null      float32
#  2   precipitation_sum                    6 non-null      float32
#  3   wind_speed_10m_max                   6 non-null      float32
#  4   wind_direction_10m_dominant          6 non-null      float32
#  5   city                                 6 non-null      object
#  6   cloud_cover                          6 non-null      int64
#  7   temperature_2m_mean_minus_1          5 non-null      float32
#  8   temperature_2m_mean_minus_2          4 non-null      float32
#  9   temperature_2m_mean_minus_3          3 non-null      float32
#  10  precipitation_sum_minus_1            5 non-null      float32
#  11  precipitation_sum_minus_2            4 non-null      float32
#  12  precipitation_sum_minus_3            3 non-null      float32
#  13  wind_speed_10m_max_minus_1           5 non-null      float32
#  14  wind_speed_10m_max_minus_2           4 non-null      float32
#  15  wind_speed_10m_max_minus_3           3 non-null      float32
#  16  wind_direction_10m_dominant_minus_1  5 non-null      float32
#  17  wind_direction_10m_dominant_minus_2  4 non-null      float32
#  18  wind_direction_10m_dominant_minus_3  3 non-null      float32
#  19  cloud_cover_minus_1                  5 non-null      float64
#  20  cloud_cover_minus_2                  4 non-null      float64
#  21  cloud_cover_minus_3                  3 non-null      float64
#  22  predicted_pm25                       6 non-null      float32
# dtypes: datetime64[us](1), float32(17), float64(3), int64(1), object(1)
# memory usage: 824.0+ bytes

# %% [markdown]
# ### <span style="color:#ff5f27;">🤖 Saving the predictions (for monitoring) to a Feature Group</span>

# %%
batch_data['street'] = street
batch_data['city'] = city
batch_data['country'] = country
# Fill in the number of days before the date on which you made the forecast (base_date)
batch_data['days_before_forecast_day'] = range(1, len(batch_data)+1)
batch_data = batch_data.sort_values(by=['date'])
batch_data
# Out:
#         date  temperature_2m_mean  precipitation_sum  wind_speed_10m_max  \
# 1 2025-11-18                 0.25                0.0           11.520000
# 0 2025-11-19                 2.05                0.4            2.545584
# 4 2025-11-20                 5.20                0.0            6.214563
# 5 2025-11-21                 5.60                0.0            3.096837
# 3 2025-11-22                 5.75                0.0            9.360000
# 2 2025-11-23                -1.25                0.0            2.305125
#
#    wind_direction_10m_dominant    city  cloud_cover  \
# 1                   270.000000  berlin           52
# 0                   224.999893  berlin           92
# 4                    10.007925  berlin           99
# 5                   215.537766  berlin           90
# 3                   360.000000  berlin           93
# 2                   321.340179  berlin           40
#
#    temperature_2m_mean_minus_1  temperature_2m_mean_minus_2  \
# 1                         2.05                          NaN
# 0                          NaN                          NaN
# 4                         5.75                        -1.25
# 5                         5.20                         5.75
# 3                        -1.25                         0.25
# 2                         0.25                         2.05
#
#    temperature_2m_mean_minus_3  ...  wind_direction_10m_dominant_minus_1  \
# 1                          NaN  ...                           224.999893
# 0                          NaN  ...                                  NaN
# 4                         0.25  ...                           360.000000
# 5                        -1.25  ...                            10.007925
# 3                         2.05  ...                           321.340179
# 2                          NaN  ...                           270.000000
#
#    wind_direction_10m_dominant_minus_2  wind_direction_10m_dominant_minus_3  \
# 1                                  NaN                                  NaN
# 0                                  NaN                                  NaN
# 4                           321.340179                           270.000000
# 5                           360.000000                           321.340179
# 3                           270.000000                           224.999893
# 2                           224.999893                                  NaN
#
#    cloud_cover_minus_1  cloud_cover_minus_2  cloud_cover_minus_3  \
# 1                 92.0                  NaN                  NaN
# 0                  NaN                  NaN                  NaN
# 4                 93.0                 40.0                 52.0
# 5                 99.0                 93.0                 40.0
# 3                 40.0                 52.0                 92.0
# 2                 52.0                 92.0                  NaN
#
#    predicted_pm25                 street  country  days_before_forecast_day
# 1       43.181931  mitte--bruckenstrasse  germany                         2
# 0       24.681555  mitte--bruckenstrasse  germany                         1
# 4       40.796795  mitte--bruckenstrasse  germany                         5
# 5       25.262087  mitte--bruckenstrasse  germany                         6
# 3       37.414093  mitte--bruckenstrasse  germany                         4
# 2       49.010216  mitte--bruckenstrasse  germany                         3
#
# [6 rows x 26 columns]

# %%
batch_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 1 to 2
# Data columns (total 26 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   date                                 6 non-null      datetime64[us]
#  1   temperature_2m_mean                  6 non-null      float32
#  2   precipitation_sum                    6 non-null      float32
#  3   wind_speed_10m_max                   6 non-null      float32
#  4   wind_direction_10m_dominant          6 non-null      float32
#  5   city                                 6 non-null      object
#  6   cloud_cover                          6 non-null      int64
#  7   temperature_2m_mean_minus_1          5 non-null      float32
#  8   temperature_2m_mean_minus_2          4 non-null      float32
#  9   temperature_2m_mean_minus_3          3 non-null      float32
#  10  precipitation_sum_minus_1            5 non-null      float32
#  11  precipitation_sum_minus_2            4 non-null      float32
#  12  precipitation_sum_minus_3            3 non-null      float32
#  13  wind_speed_10m_max_minus_1           5 non-null      float32
#  14  wind_speed_10m_max_minus_2           4 non-null      float32
#  15  wind_speed_10m_max_minus_3           3 non-null      float32
#  16  wind_direction_10m_dominant_minus_1  5 non-null      float32
#  17  wind_direction_10m_dominant_minus_2  4 non-null      float32
#  18  wind_direction_10m_dominant_minus_3  3 non-null      float32
#  19  cloud_cover_minus_1                  5 non-null      float64
#  20  cloud_cover_minus_2                  4 non-null      float64
#  21  cloud_cover_minus_3                  3 non-null      float64
#  22  predicted_pm25                       6 non-null      float32
#  23  street                               6 non-null      object
#  24  country                              6 non-null      object
#  25  days_before_forecast_day             6 non-null      int64
# dtypes: datetime64[us](1), float32(17), float64(3), int64(2), object(3)
# memory usage: 888.0+ bytes

# %% [markdown]
# ### Create Forecast Graph
# Draw a graph of the predictions with dates as a PNG and save it to the github repo
# Show it on github pages

# %%
pred_file_path = f"{root_dir}/docs/air-quality/assets/img/pm25_forecast_cloud_cover_lag.png"
plt = util.plot_air_quality_forecast(city, street, batch_data, pred_file_path)

plt.show()
# Out:
# 2025-11-17 21:11:23,763 WARNING: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.

# %%
# Get or create feature group
monitor_fg = fs.get_or_create_feature_group(
    name='aq_predictions_cloud_cover_lag',
    description='Air Quality prediction monitoring',
    version=1,
    primary_key=['city','street','date','days_before_forecast_day'],
    event_time="date"
)

# %%
print("DataFrame columns:", batch_data.columns.tolist())
# Out:
# DataFrame columns: ['date', 'temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 'wind_direction_10m_dominant', 'city', 'cloud_cover', 'temperature_2m_mean_minus_1', 'temperature_2m_mean_minus_2', 'temperature_2m_mean_minus_3', 'precipitation_sum_minus_1', 'precipitation_sum_minus_2', 'precipitation_sum_minus_3', 'wind_speed_10m_max_minus_1', 'wind_speed_10m_max_minus_2', 'wind_speed_10m_max_minus_3', 'wind_direction_10m_dominant_minus_1', 'wind_direction_10m_dominant_minus_2', 'wind_direction_10m_dominant_minus_3', 'cloud_cover_minus_1', 'cloud_cover_minus_2', 'cloud_cover_minus_3', 'predicted_pm25', 'street', 'country', 'days_before_forecast_day']

# %%
expected_cols = [f.name for f in monitor_fg.features]
print("Feature Group columns:", expected_cols)
# Out:
# Feature Group columns: ['date', 'temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 'wind_direction_10m_dominant', 'city', 'cloud_cover', 'temperature_2m_mean_minus_1', 'temperature_2m_mean_minus_2', 'temperature_2m_mean_minus_3', 'precipitation_sum_minus_1', 'precipitation_sum_minus_2', 'precipitation_sum_minus_3', 'wind_speed_10m_max_minus_1', 'wind_speed_10m_max_minus_2', 'wind_speed_10m_max_minus_3', 'wind_direction_10m_dominant_minus_1', 'wind_direction_10m_dominant_minus_2', 'wind_direction_10m_dominant_minus_3', 'cloud_cover_minus_1', 'cloud_cover_minus_2', 'cloud_cover_minus_3', 'predicted_pm25', 'street', 'country', 'days_before_forecast_day']

# %%
#monitor_fg.delete()

# %%
print(batch_data.columns)
# Out:
# Index(['date', 'temperature_2m_mean', 'precipitation_sum',
#        'wind_speed_10m_max', 'wind_direction_10m_dominant', 'city',
#        'cloud_cover', 'temperature_2m_mean_minus_1',
#        'temperature_2m_mean_minus_2', 'temperature_2m_mean_minus_3',
#        'precipitation_sum_minus_1', 'precipitation_sum_minus_2',
#        'precipitation_sum_minus_3', 'wind_speed_10m_max_minus_1',
#        'wind_speed_10m_max_minus_2', 'wind_speed_10m_max_minus_3',
#        'wind_direction_10m_dominant_minus_1',
#        'wind_direction_10m_dominant_minus_2',
#        'wind_direction_10m_dominant_minus_3', 'cloud_cover_minus_1',
#        'cloud_cover_minus_2', 'cloud_cover_minus_3', 'predicted_pm25',
#        'street', 'country', 'days_before_forecast_day'],
#       dtype='object')

# %%
monitor_fg.insert(batch_data, wait=True)
# Out:
# Uploading Dataframe: 100.00% |██████████| Rows 6/6 | Elapsed Time: 00:01 | Remaining Time: 00:00
# Launching job: aq_predictions_cloud_cover_lag_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1271978/jobs/named/aq_predictions_cloud_cover_lag_1_offline_fg_materialization/executions
# 2025-11-17 21:11:43,239 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2025-11-17 21:11:46,465 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# 2025-11-17 21:13:21,348 INFO: Waiting for execution to finish. Current state: AGGREGATING_LOGS. Final status: SUCCEEDED
# 2025-11-17 21:13:21,518 INFO: Waiting for log aggregation to finish.
# 2025-11-17 21:13:30,286 INFO: Execution finished successfully.
# (Job('aq_predictions_cloud_cover_lag_1_offline_fg_materialization', 'SPARK'),
#  None)

# %%
# We will create a hindcast chart for  only the forecasts made 1 day beforehand
monitoring_df = monitor_fg.filter(monitor_fg.days_before_forecast_day == 1).read()
monitoring_df
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.44s)
#                        date  temperature_2m_mean  precipitation_sum  \
# 0 2025-11-19 00:00:00+00:00                 2.05                0.4
#
#    wind_speed_10m_max  wind_direction_10m_dominant    city  cloud_cover  \
# 0            2.545584                   224.999893  berlin           92
#
#    temperature_2m_mean_minus_1  temperature_2m_mean_minus_2  \
# 0                          NaN                          NaN
#
#    temperature_2m_mean_minus_3  ...  wind_direction_10m_dominant_minus_1  \
# 0                          NaN  ...                                  NaN
#
#    wind_direction_10m_dominant_minus_2  wind_direction_10m_dominant_minus_3  \
# 0                                  NaN                                  NaN
#
#    cloud_cover_minus_1  cloud_cover_minus_2  cloud_cover_minus_3  \
# 0                  NaN                  NaN                  NaN
#
#    predicted_pm25                 street  country  days_before_forecast_day
# 0       24.681555  mitte--bruckenstrasse  germany                         1
#
# [1 rows x 26 columns]

# %%
air_quality_fg = fs.get_feature_group(name='air_quality', version=1)
air_quality_df = air_quality_fg.read()
air_quality_df
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.04s)
#                           date  pm25  country    city                 street  \
# 0    2025-05-14 00:00:00+00:00  40.0  germany  berlin  mitte--bruckenstrasse
# 1    2024-02-22 00:00:00+00:00  24.0  germany  berlin  mitte--bruckenstrasse
# 2    2022-11-27 00:00:00+00:00  65.0  germany  berlin  mitte--bruckenstrasse
# 3    2024-09-20 00:00:00+00:00  61.0  germany  berlin  mitte--bruckenstrasse
# 4    2023-01-29 00:00:00+00:00  58.0  germany  berlin  mitte--bruckenstrasse
# ...                        ...   ...      ...     ...                    ...
# 1355 2024-11-05 00:00:00+00:00  61.0  germany  berlin  mitte--bruckenstrasse
# 1356 2023-07-01 00:00:00+00:00  36.0  germany  berlin  mitte--bruckenstrasse
# 1357 2022-06-23 00:00:00+00:00  34.0  germany  berlin  mitte--bruckenstrasse
# 1358 2025-04-30 00:00:00+00:00  33.0  germany  berlin  mitte--bruckenstrasse
# 1359 2022-10-03 00:00:00+00:00  33.0  germany  berlin  mitte--bruckenstrasse
#
#                                     url
# 0     https://api.waqi.info/feed/@10039
# 1     https://api.waqi.info/feed/@10039
# 2     https://api.waqi.info/feed/@10039
# 3     https://api.waqi.info/feed/@10039
# 4     https://api.waqi.info/feed/@10039
# ...                                 ...
# 1355  https://api.waqi.info/feed/@10039
# 1356  https://api.waqi.info/feed/@10039
# 1357  https://api.waqi.info/feed/@10039
# 1358  https://api.waqi.info/feed/@10039
# 1359  https://api.waqi.info/feed/@10039
#
# [1360 rows x 6 columns]

# %%
print(air_quality_df.columns)
print(monitoring_df.columns)
# Out:
# Index(['date', 'pm25', 'country', 'city', 'street', 'url'], dtype='object')
# Index(['date', 'temperature_2m_mean', 'precipitation_sum',
#        'wind_speed_10m_max', 'wind_direction_10m_dominant', 'city',
#        'cloud_cover', 'temperature_2m_mean_minus_1',
#        'temperature_2m_mean_minus_2', 'temperature_2m_mean_minus_3',
#        'precipitation_sum_minus_1', 'precipitation_sum_minus_2',
#        'precipitation_sum_minus_3', 'wind_speed_10m_max_minus_1',
#        'wind_speed_10m_max_minus_2', 'wind_speed_10m_max_minus_3',
#        'wind_direction_10m_dominant_minus_1',
#        'wind_direction_10m_dominant_minus_2',
#        'wind_direction_10m_dominant_minus_3', 'cloud_cover_minus_1',
#        'cloud_cover_minus_2', 'cloud_cover_minus_3', 'predicted_pm25',
#        'street', 'country', 'days_before_forecast_day'],
#       dtype='object')

# %%
print(retrieved_xgboost_model.get_booster().feature_names)
# Out:
# ['temperature_2m_mean', 'precipitation_sum', 'wind_speed_10m_max', 'wind_direction_10m_dominant', 'cloud_cover', 'temperature_2m_mean_minus_1', 'temperature_2m_mean_minus_2', 'temperature_2m_mean_minus_3', 'precipitation_sum_minus_1', 'precipitation_sum_minus_2', 'precipitation_sum_minus_3', 'wind_speed_10m_max_minus_1', 'wind_speed_10m_max_minus_2', 'wind_speed_10m_max_minus_3', 'wind_direction_10m_dominant_minus_1', 'wind_direction_10m_dominant_minus_2', 'wind_direction_10m_dominant_minus_3', 'cloud_cover_minus_1', 'cloud_cover_minus_2', 'cloud_cover_minus_3']

# %%
outcome_df = air_quality_df[['date', 'pm25']]
preds_df =  monitoring_df[['date', 'predicted_pm25']]

hindcast_df = pd.merge(preds_df, outcome_df, on="date")
hindcast_df = hindcast_df.sort_values(by=['date'])

# If there are no outcomes for predictions yet, generate some predictions/outcomes from existing data
if len(hindcast_df) == 0:
    hindcast_df = util.backfill_predictions_for_monitoring_cloud_cover_lag(weather_fg, air_quality_df, monitor_fg, retrieved_xgboost_model)
hindcast_df
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.04s)
# ---------------------------------------------------------------------------
# FeatureStoreException                     Traceback (most recent call last)
# Cell In[29], line 9
#       7 # If there are no outcomes for predictions yet, generate some predictions/outcomes from existing data
#       8 if len(hindcast_df) == 0:
# ----> 9     hindcast_df = util.backfill_predictions_for_monitoring_cloud_cover_lag(weather_fg, air_quality_df, monitor_fg, retrieved_xgboost_model)
#      10 hindcast_df
#
# File /mnt/c/Users/t-kaspermalm/Documents/code/github/kth/mlfs-book/mlfs/airquality/util.py:360, in backfill_predictions_for_monitoring_cloud_cover_lag(weather_fg, air_quality_df, monitor_fg, model)
#     357 df['cloud_cover_minus_2'] = df['cloud_cover_minus_2'].astype('float32')
#     358 df['cloud_cover_minus_3'] = df['cloud_cover_minus_3'].astype('float32')
# --> 360 monitor_fg.insert(df, write_options={"wait_for_job": True})
#     361 return hindcast_df
#
# File ~/miniconda3/envs/aq/lib/python3.10/site-packages/hsfs/feature_group.py:3153, in FeatureGroup.insert(self, features, overwrite, operation, storage, write_options, validation_options, wait, transformation_context, transform)
#    3150 if not self._id and self._offline_backfill_every_hr is not None:
#    3151     write_options["offline_backfill_every_hr"] = self._offline_backfill_every_hr
# -> 3153 job, ge_report = self._feature_group_engine.insert(
#    3154     self,
#    3155     feature_dataframe=feature_dataframe,
#    3156     overwrite=overwrite,
#    3157     operation=operation,
#    3158     storage=storage.lower() if storage is not None else None,
#    3159     write_options=write_options,
#    3160     validation_options={"save_report": True, **validation_options},
#    3161     transformation_context=transformation_context,
#    3162     transform=transform,
#    3163 )
#    3165 if engine.get_type().startswith("spark") and not self.stream:
#    3166     # Also, only compute statistics if stream is False.
#    3167     # if True, the backfill job has not been triggered and the data has not been inserted (it's in Kafka)
#    3168     self.compute_statistics()
#
# File ~/miniconda3/envs/aq/lib/python3.10/site-packages/hsfs/core/feature_group_engine.py:209, in FeatureGroupEngine.insert(self, feature_group, feature_dataframe, overwrite, operation, storage, write_options, validation_options, transformation_context, transform)
#     204     self.save_feature_group_metadata(
#     205         feature_group, dataframe_features, write_options
#     206     )
#     207 else:
#     208     # else, just verify that feature group schema matches user-provided dataframe
# --> 209     self._verify_schema_compatibility(
#     210         feature_group.features, dataframe_features
#     211     )
#     213 # ge validation on python and non stream feature groups on spark
#     214 ge_report = feature_group._great_expectation_engine.validate(
#     215     feature_group=feature_group,
#     216     dataframe=feature_dataframe,
#    (...)
#     219     ge_type=False,
#     220 )
#
# File ~/miniconda3/envs/aq/lib/python3.10/site-packages/hsfs/core/feature_group_base_engine.py:186, in FeatureGroupBaseEngine._verify_schema_compatibility(self, feature_group_features, dataframe_features)
#     184 # raise exception if any errors were found.
#     185 if len(err) > 0:
# --> 186     raise FeatureStoreException(
#     187         "Features are not compatible with Feature Group schema: "
#     188         + "".join(["\n - " + e for e in err])
#     189         + "\nNote that feature (or column) names are case insensitive and "
#     190         "spaces are automatically replaced with underscores."
#     191     )
#
# FeatureStoreException: Features are not compatible with Feature Group schema:
#  - cloud_cover_minus_1 (expected type: 'double', derived from input: 'bigint') has the wrong type.
#  - cloud_cover_minus_2 (expected type: 'double', derived from input: 'float') has the wrong type.
#  - cloud_cover_minus_3 (expected type: 'double', derived from input: 'float') has the wrong type.
# Note that feature (or column) names are case insensitive and spaces are automatically replaced with underscores.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

y_true = hindcast_df['pm25']
y_pred = hindcast_df['predicted_pm25']

mae = mean_absolute_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
mean_error = (y_pred - y_true).mean()
std_error = (y_pred - y_true).std()
r2 = r2_score(y_true, y_pred)

print(f"Mean Error: {mean_error:.2f}")
print(f"Std of Error: {std_error:.2f}")
print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R²: {r2:.2f}")
# Out:
# 2025-11-17 16:43:51,365 WARNING: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# 2025-11-17 16:43:51,366 WARNING: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 7
#       4 y_true = hindcast_df['pm25']
#       5 y_pred = hindcast_df['predicted_pm25']
# ----> 7 mae = mean_absolute_error(y_true, y_pred)
#       8 mse = mean_squared_error(y_true, y_pred)
#       9 rmse = np.sqrt(mse)
#
# File ~/miniconda3/envs/aq/lib/python3.10/site-packages/sklearn/metrics/_regression.py:196, in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     141 def mean_absolute_error(
#     142     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average"
#     143 ):
#     144     """Mean absolute error regression loss.
#     145
#     146     Read more in the :ref:`User Guide <mean_absolute_error>`.
#    (...)
#     194     0.85...
#     195     """
# --> 196     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     197         y_true, y_pred, multioutput
#     198     )
#     199     check_consistent_length(y_true, y_pred, sample_weight)
#     200     output_errors = np.average(np.abs(y_pred - y_true), weights=sample_weight, axis=0)
#
# File ~/miniconda3/envs/aq/lib/python3.10/site-packages/sklearn/metrics/_regression.py:101, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      67 """Check that y_true and y_pred belong to the same regression task.
#      68
#      69 Parameters
#    (...)
#      98     correct keyword.
#      99 """
#     100 check_consistent_length(y_true, y_pred)
# --> 101 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     102 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     104 if y_true.ndim == 1:
#
# File ~/miniconda3/envs/aq/lib/python3.10/site-packages/sklearn/utils/validation.py:931, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     929     n_samples = _num_samples(array)
#     930     if n_samples < ensure_min_samples:
# --> 931         raise ValueError(
#     932             "Found array with %d sample(s) (shape=%s) while a"
#     933             " minimum of %d is required%s."
#     934             % (n_samples, array.shape, ensure_min_samples, context)
#     935         )
#     937 if ensure_min_features > 0 and array.ndim == 2:
#     938     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.

# %% [markdown]
# ### Plot the Hindcast comparing predicted with forecasted values (1-day prior forecast)
#
# __This graph will be empty to begin with - this is normal.__
#
# After a few days of predictions and observations, you will get data points in this graph.

# %%
hindcast_file_path = f"{root_dir}/docs/air-quality/assets/img/pm25_hindcast_1day_cloud_cover_lag.png"
plt = util.plot_air_quality_forecast(city, street, hindcast_df, hindcast_file_path, hindcast=True)
plt.show()

# %% [markdown]
# ### Upload the prediction and hindcast dashboards (png files) to Hopsworks

# %%
dataset_api = project.get_dataset_api()
str_today = today.strftime("%Y-%m-%d")
if dataset_api.exists("Resources/airquality") == False:
    dataset_api.mkdir("Resources/airquality")
dataset_api.upload(pred_file_path, f"Resources/airquality/{city}_{street}_{str_today}_cloud_cover_lag", overwrite=True)
dataset_api.upload(hindcast_file_path, f"Resources/airquality/{city}_{street}_{str_today}_cloud_cover_lag", overwrite=True)

proj_url = project.get_url()
print(f"See images in Hopsworks here: {proj_url}/settings/fb/path/Resources/airquality")

# %% [markdown]
# ---
